# %% [markdown]
# <a href="https://colab.research.google.com/github/anghelarivera18-art/Notebooks_Agro_2026_1/blob/main/Rendimiento_Extracci%C3%B3n_Aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Control de Rendimiento en Extracción de Aceite**
#
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento**:
#
# Una planta procesadora de palma de aceite necesita calcular el **Índice de Rendimiento de Extracción (IRE)**. El operario debe ingresar el **peso total de los racimos de fruta fresca (RFF)** procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos**:
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float).(pr)
# 3. Solicitar los litros de aceite obtenidos (Tipo float).(lt)
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L.(r)
#
# $$pa =lt * 0.92$$
#
# $$ r=(pa/pr) * 100$$
#
# **Prueba del programa:**
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.

# %%
# ENTRADA: Ingresa Solicitar el nombre del lote de producción (Tipo string).
#Solicitar el peso de los racimos en kg (Tipo float).(pr)
#Solicitar los litros de aceite obtenidos (Tipo float).(lt)
nombre = input("ingrese el nombre del lote")
pr = float(input("ingrese el peso de los racimos en kg"))
lt = float(input("ingrese la cantidad de aceite crudo obtenido en litros"))

# PROCESO: calcular peso del aceite (pa) y el rendimiento (r)
pa = lt * 0.92
r = (pa/pr) * 100

# SALIDA: Informar el rendimiento del lote
print("el rendimiento del lote", nombre, "es del", r, "%")
# Out:
# ingrese el nombre del loteel perico
# ingrese el peso de los racimos en kg1000
# ingrese la cantidad de aceite crudo obtenido en litros200
# el rendimiento del lote el perico es del 18.4 %
# ingrese el nombre del lote el perico

# %% [markdown]
# ```markdown
# Aquí está la explicación de cada línea de código del problema "Control de Rendimiento en Extracción de Aceite":
#
# ```python
# # ENTRADA: Ingresa Solicitar el nombre del lote de producción (Tipo string).
# #Solicitar el peso de los racimos en kg (Tipo float).(pr)
# #Solicitar los litros de aceite obtenidos (Tipo float).(lt)
# ```
# Estas líneas son comentarios (`#`) que sirven para documentar el código. Indican qué tipo de datos se solicitan al usuario en la sección de entrada:
# - El nombre del lote de producción (string).
# - El peso de los racimos en kilogramos (float), representado por la variable `pr`.
# - Los litros de aceite obtenidos (float), representado por la variable `lt`.
#
# ```python
# nombre = input("ingrese el nombre del lote")
# ```
# Esta línea solicita al usuario que ingrese el nombre del lote de producción. La función `input()` muestra el mensaje "ingrese el nombre del lote" en la consola, espera la entrada del usuario y el texto ingresado se guarda en la variable `nombre` (de tipo string).
#
# ```python
# pr = float(input("ingrese el peso de los racimos en kg"))
# ```
# Esta línea solicita al usuario el peso de los racimos en kilogramos. Similar a la anterior, `input()` muestra un mensaje, pero el valor ingresado es convertido a un número de punto flotante (`float`) usando `float()` antes de ser asignado a la variable `pr`. Esto es importante porque los pesos suelen tener decimales.
#
# ```python
# lt = float(input("ingrese la cantidad de aceite crudo obtenido en litros"))
# ```
# Aquí se solicita al usuario la cantidad de aceite crudo obtenida en litros. El valor ingresado es también convertido a `float` y almacenado en la variable `lt`, ya que los volúmenes pueden tener decimales.
#
# ```python
# # PROCESO: calcular peso del aceite (pa) y el rendimiento (r)
# ```
# Este comentario indica que las siguientes líneas realizan los cálculos necesarios para el problema.
#
# ```python
# pa = lt * 0.92
# ```
# Esta línea calcula el peso del aceite (`pa`). Multiplica los litros de aceite obtenidos (`lt`) por la densidad del aceite (0.92 kg/L). El resultado se guarda en la variable `pa`.
#
# ```python
# r = (pa/pr) * 100
# ```
# Esta línea calcula el Índice de Rendimiento de Extracción (`r`). Divide el peso del aceite (`pa`) por el peso de los racimos (`pr`) y luego multiplica el resultado por 100 para obtener un porcentaje. El valor final se almacena en la variable `r`.
#
# ```python
# # SALIDA: Informar el rendimiento del lote
# ```
# Este comentario indica que la siguiente línea mostrará el resultado al usuario.
#
# ```python
# print("el rendimiento del lote", nombre, "es del", r, "%")
# ```
# Esta línea imprime el resultado final en la consola. Utiliza la función `print()` para concatenar varias cadenas de texto y variables (`nombre` y `r`) para formar un mensaje legible que informa el rendimiento del lote. Por ejemplo, si `nombre` es "Lote A" y `r` es 18.4, la salida sería: "el rendimiento del lote Lote A es del 18.4 %"
# ```
